# %% [markdown]
# # **Scrapping Data Twitter with SNSCRAPE**

# %% [markdown]
# **Data Analysis**
#
# → Teknik Pengumpulan Data Sekunder :
# 1.   Metode Analisis Kualitatif
#     *   Wawancara, Observasi dan Literatur
#     *   Teks atau Narasi
#     *   Klasifikasi dan Interpretasi
#     *   Pendekatan Subjektif
#     *   Kedalaman Hasil Analisisnya
# 2.   Metode Analisis Kuantitatif
#     *   Data Tabular
#     *   Analisis Deskriptif, Korelasi, Regresi, Komparasi dll
#     *   Terukur dan Komprehensif
#     *   Pendekatan Statistik dan Matematik

# %% [markdown]
# SCRAPPING vs CRAWLING
#
# *   Crawling Data
#     *   Indexing Pages using URL (Uniform Resource Locator) with API (Application Programming Interface)
#     *   BOT / Spider for Seach Engine
#
#     How it Works?
#     1.   Search URL
#     2.   Explore Web Address
#     3.   Identify every pages
#     4.   Indexing & Updating File
#     5.   Web Frequency using robots.txt for communicate and identiy content
#
#
# *   Scrapping Data
#     *   Data Extraction from Website
#     *   Parsing using HTML / XML
#     *   Focused Approach

# %% [markdown]
# LIBRARY SNSSCRAPE
# - Python 3.8 or Higher
# - Development Version or Normally
# - json argument instead of just tweet URLs
# - More Useful Functionality
#
# LIBRARY PANDAS
# - Pandas Object : DataFrame and Series
# - Read Files
# - Explore Data Charachteristic
#
# LIBRARY NUMPY (Numerical Python)
# - Multidimentional Arrays
# - Matrix Calculation
# - Algebra
#
#
# LIBRARY ITERTOOLS
# - Fast and Memory-Efficient Tool for Multiplying or Iterating Elements

# %%
import pandas as pd
import numpy as np
import csv

# %%
x = pd.Series([4, 3, 9, 6])
print(x)
# Out:
# 0    4
# 1    3
# 2    9
# 3    6
# dtype: int64

# %%
x.index = ['a', 'b', 'c', 'd']
print(x)
# Out:
# a    4
# b    3
# c    9
# d    6
# dtype: int64

# %%
y = pd.Series([4, 2, 7, 8], index=['a', 'b', 'c', 'd'])
print(y)
# Out:
# a    4
# b    2
# c    7
# d    8
# dtype: int64

# %%
df = pd.DataFrame({'angkanih': [50, 100, 150], 'hurufnih': ['a', 'b', 'c']})
print(df)
# Out:
#    angkanih hurufnih
# 0        50        a
# 1       100        b
# 2       150        c

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# !pip install snscrape

# %%
import snscrape.modules.twitter as sntwitter
import itertools

# %%
#scraping data with keyword vaksin
df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
   'vaksin').get_items(), 100))[['username', 'date', 'content']]

# %%
df.head()
# Out:
#     username  ...                                            content
# 0  mfidris38  ...  @f4kr0ls00d Menteri tkda otak, suruh bgi vaksi...
# 1   Jebaylee  ...  Pak RT Dateng ke rumah tdinya mau mamah aja yg...
# 2    rmol_id  ...             Vaksin Booster https://t.co/0KQgoFm8cb
# 3  bosbesars  ...    Di karenakan covid makin parah mari kita vaksin
# 4    mootsmu  ...  @afrkml @hrjn_ @rennydesavi kalo ngga dikasih ...
#
# [5 rows x 3 columns]

# %%
df.tail()
# Out:
#          username  ...                                            content
# 95      Ciel_duke  ...  eh kemaren ada yang ngetwit do and dont pasca ...
# 96  MommaBear0716  ...  Covidsmart,\nKabar baik buat kamu nih,\nJd drp...
# 97  fananinurhuda  ...  @papa_piyo @trendingtopiq diadu apanya dah... ...
# 98  galamedianews  ...  Vaksinasi Massal Digelar, Presiden #Jokowi: Ta...
# 99   BambangTenan  ...  Gue di vaksin Astra Zaneca. Kata MAJELIS ULAMA...
#
# [5 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   username  100 non-null    object
#  1   date      100 non-null    datetime64[ns, UTC]
#  2   content   100 non-null    object
# dtypes: datetime64[ns, UTC](1), object(2)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#           username  ...                                            content
# count          100  ...                                                100
# unique          91  ...                                                100
# top     piramarisa  ...  Di Vietnam jg melibatkan masy/influencer untuk...
# freq             4  ...                                                  1
# first          NaN  ...                                                NaN
# last           NaN  ...                                                NaN
#
# [6 rows x 3 columns]

# %%
df
# Out:
#          username  ...                                            content
# 0       mfidris38  ...  @f4kr0ls00d Menteri tkda otak, suruh bgi vaksi...
# 1        Jebaylee  ...  Pak RT Dateng ke rumah tdinya mau mamah aja yg...
# 2         rmol_id  ...             Vaksin Booster https://t.co/0KQgoFm8cb
# 3       bosbesars  ...    Di karenakan covid makin parah mari kita vaksin
# 4         mootsmu  ...  @afrkml @hrjn_ @rennydesavi kalo ngga dikasih ...
# ..            ...  ...                                                ...
# 95      Ciel_duke  ...  eh kemaren ada yang ngetwit do and dont pasca ...
# 96  MommaBear0716  ...  Covidsmart,\nKabar baik buat kamu nih,\nJd drp...
# 97  fananinurhuda  ...  @papa_piyo @trendingtopiq diadu apanya dah... ...
# 98  galamedianews  ...  Vaksinasi Massal Digelar, Presiden #Jokowi: Ta...
# 99   BambangTenan  ...  Gue di vaksin Astra Zaneca. Kata MAJELIS ULAMA...
#
# [100 rows x 3 columns]

# %%
df['content']
# Out:
# 0     @f4kr0ls00d Menteri tkda otak, suruh bgi vaksi...
# 1     Pak RT Dateng ke rumah tdinya mau mamah aja yg...
# 2                Vaksin Booster https://t.co/0KQgoFm8cb
# 3       Di karenakan covid makin parah mari kita vaksin
# 4     @afrkml @hrjn_ @rennydesavi kalo ngga dikasih ...
#                             ...
# 95    eh kemaren ada yang ngetwit do and dont pasca ...
# 96    Covidsmart,\nKabar baik buat kamu nih,\nJd drp...
# 97    @papa_piyo @trendingtopiq diadu apanya dah... ...
# 98    Vaksinasi Massal Digelar, Presiden #Jokowi: Ta...
# 99    Gue di vaksin Astra Zaneca. Kata MAJELIS ULAMA...
# Name: content, Length: 100, dtype: object

# %%
df = df.drop(columns=['username', 'date'])

# %%
df
# Out:
#                                               content
# 0   @f4kr0ls00d Menteri tkda otak, suruh bgi vaksi...
# 1   Pak RT Dateng ke rumah tdinya mau mamah aja yg...
# 2              Vaksin Booster https://t.co/0KQgoFm8cb
# 3     Di karenakan covid makin parah mari kita vaksin
# 4   @afrkml @hrjn_ @rennydesavi kalo ngga dikasih ...
# ..                                                ...
# 95  eh kemaren ada yang ngetwit do and dont pasca ...
# 96  Covidsmart,\nKabar baik buat kamu nih,\nJd drp...
# 97  @papa_piyo @trendingtopiq diadu apanya dah... ...
# 98  Vaksinasi Massal Digelar, Presiden #Jokowi: Ta...
# 99  Gue di vaksin Astra Zaneca. Kata MAJELIS ULAMA...
#
# [100 rows x 1 columns]

# %%
df.content=df.content.astype(str)

# %%
df
# Out:
#                                               content
# 0   @f4kr0ls00d Menteri tkda otak, suruh bgi vaksi...
# 1   Pak RT Dateng ke rumah tdinya mau mamah aja yg...
# 2              Vaksin Booster https://t.co/0KQgoFm8cb
# 3     Di karenakan covid makin parah mari kita vaksin
# 4   @afrkml @hrjn_ @rennydesavi kalo ngga dikasih ...
# ..                                                ...
# 95  eh kemaren ada yang ngetwit do and dont pasca ...
# 96  Covidsmart,\nKabar baik buat kamu nih,\nJd drp...
# 97  @papa_piyo @trendingtopiq diadu apanya dah... ...
# 98  Vaksinasi Massal Digelar, Presiden #Jokowi: Ta...
# 99  Gue di vaksin Astra Zaneca. Kata MAJELIS ULAMA...
#
# [100 rows x 1 columns]

# %%
df.to_csv('/content/drive/MyDrive/SA BISA AI/dataset.csv', index=None)

# %% [markdown]
# # Data Preparation & Cleaning using NLTK

# %%
df = pd.read_csv('/content/drive/MyDrive/SA BISA AI/dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8df5efb8e67d> in <module>()
# ----> 1 df = pd.read_csv('/content/drive/MyDrive/SA BISA AI/dataset.csv')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# **lambda args : expression**
#
# lambda : keyword untuk membuat fungsi lambda
#
# args : argumen / parameter
#
# expression : isi fungsi

# %%
#  Cleaning text
import re
import string

def clean_text(tweet):
    tweet = tweet.lower() # text lowercase
    tweet = re.sub('@[^\s]+', '', tweet) # remove usernames
    tweet = re.sub('\[.*?\]', '', tweet) # remove square brackets
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', tweet) # remove URLs
    tweet = re.sub('[%s]' % re.escape(string.punctuation), '', tweet) # remove punctuation
    tweet = re.sub('\w*\d\w*', '', tweet) 
    tweet = re.sub('[‘’“”…]', '', tweet)
    tweet = re.sub('\n', '', tweet)
    return tweet

    
tweet = lambda x: clean_text(x)

# %%
df['clean1'] = pd.DataFrame(df.content.apply(tweet))
df

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
additional  = ['rt','rts','retweet']
swords = set().union(stopwords.words('indonesian'), additional)

df['clean2'] = (df['clean1'].apply(lambda x: ' '.join([word for word in x.split() if word not in (swords)])))
df

# %%
text = df['clean2']

# %% [markdown]
# ### Sastrawi

# %%
# !pip install Sastrawi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

list_hasil = text

output = [(stemmer.stem(token)) for token in list_hasil]

# %%
df['clean3'] = output

# %%
df

# %%
df.dropna()

# %%
import nltk
nltk.download('punkt')

# %%
df['tokens'] = pd.DataFrame(df['clean3'].apply(nltk.word_tokenize))
df

# %%
#terjemahkan data ke english
# !pip install google_trans_new

# %%
from google_trans_new import google_translator  

translator = google_translator()

# %%
detect_text = translator.detect('apa kabar?')  
detect_text

# %%
translate_text = translator.translate('apa kabar ?', lang_tgt='en')
translate_text

# %%
def translate_column(text, target_language):
    return translator.translate(text, lang_tgt=target_language)

# %%
df['clean_english'] = df['clean3'].apply(lambda x: translate_column(x, 'en'))

# %%
df

# %%
df.to_csv('/content/drive/MyDrive/mini-bootcamp/dataset_clean.csv', index=None)
