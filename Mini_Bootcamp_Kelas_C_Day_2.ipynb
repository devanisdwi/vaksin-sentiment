# %% [markdown]
# # **Scrapping Data Twitter with SNSCRAPE**

# %% [markdown]
# # New Section

# %% [markdown]
# **Data Analysis**
#
# → Teknik Pengumpulan Data Sekunder :
# 1.   Metode Analisis Kualitatif
#     *   Wawancara, Observasi dan Literatur
#     *   Teks atau Narasi
#     *   Klasifikasi dan Interpretasi
#     *   Pendekatan Subjektif
#     *   Kedalaman Hasil Analisisnya
# 2.   Metode Analisis Kuantitatif
#     *   Data Tabular
#     *   Analisis Deskriptif, Korelasi, Regresi, Komparasi dll
#     *   Terukur dan Komprehensif
#     *   Pendekatan Statistik dan Matematik

# %% [markdown]
# SCRAPPING vs CRAWLING
#
# *   Crawling Data
#     *   Indexing Pages using URL (Uniform Resource Locator) with API (Application Programming Interface)
#     *   BOT / Spider for Seach Engine
#
#     How it Works?
#     1.   Search URL
#     2.   Explore Web Address
#     3.   Identify every pages
#     4.   Indexing & Updating File
#     5.   Web Frequency using robots.txt for communicate and identiy content
#
#
# *   Scrapping Data
#     *   Data Extraction from Website
#     *   Parsing using HTML / XML
#     *   Focused Approach

# %% [markdown]
# LIBRARY SNSSCRAPE
# - Python 3.8 or Higher
# - Development Version or Normally
# - json argument instead of just tweet URLs
# - More Useful Functionality
#
# LIBRARY PANDAS
# - Pandas Object : DataFrame and Series
# - Read Files
# - Explore Data Charachteristic
#
# LIBRARY NUMPY (Numerical Python)
# - Multidimentional Arrays
# - Matrix Calculation
# - Algebra
#
#
# LIBRARY ITERTOOLS
# - Fast and Memory-Efficient Tool for Multiplying or Iterating Elements

# %%
import pandas as pd
import numpy as np
import csv

# %%
x = pd.Series([4, 3, 9, 6])
print(x)
# Out:
# 0    4
# 1    3
# 2    9
# 3    6
# dtype: int64

# %%
x.index = ['a', 'b', 'c', 'd']
print(x)
# Out:
# a    4
# b    3
# c    9
# d    6
# dtype: int64

# %%
y = pd.Series([4, 2, 7, 8], index=['a', 'b', 'c', 'd'])
print(y)
# Out:
# a    4
# b    2
# c    7
# d    8
# dtype: int64

# %%
df = pd.DataFrame({'angkanih': [50, 100, 150], 'hurufnih': ['a', 'b', 'c']})
print(df)
# Out:
#    angkanih hurufnih
# 0        50        a
# 1       100        b
# 2       150        c

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# !pip install snscrape

# %%
import snscrape.modules.twitter as sntwitter
import itertools

# %%
#scraping data with keyword vaccine
df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
   'vaccine').get_items(), 100))[['username', 'date', 'content']]

# %%
df.head()
# Out:
#         username  ...                                            content
# 0  srinivas_shaz  ...  @Dev_Fadnavis Please Send Some Vaccines to Vas...
# 1       XCritter  ...  @Penseursauvage Ne fais pas l'amalgame entre c...
# 2    DavidPember  ...  @RonnieMathis2 @Value_IS_KING @BarstoolMintzy ...
# 3      Toni_Cwen  ...  @PabloSnicklefrz Faye sez hi! https://t.co/m7U...
# 4     Bebs______  ...  T'imagines si en plus de ne pas être vacciné, ...
#
# [5 rows x 3 columns]

# %%
df.tail()
# Out:
#          username  ...                                            content
# 95       gmfuster  ...  @DrEricDing Chile had the Chinese vaccine thou...
# 96   lostmixtapes  ...  astro pls wait until i get my vaccine now befo...
# 97  VaxHuntersCan  ...        @LisaPBRI If that is York Region, then yes.
# 98      Bloonface  ...  I was (and I suppose still am?) in favour of l...
# 99       Hendo968  ...                @trellejb Liking anti vaccine stuff
#
# [5 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   username  100 non-null    object
#  1   date      100 non-null    datetime64[ns, UTC]
#  2   content   100 non-null    object
# dtypes: datetime64[ns, UTC](1), object(2)
# memory usage: 2.5+ KB

# %%
df.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#             username  ...                                            content
# count            100  ...                                                100
# unique            95  ...                                                100
# top     VaccineEdgar  ...  @_JuDeKiwi @bordelow Mea culpa je voulais parl...
# freq               4  ...                                                  1
# first            NaN  ...                                                NaN
# last             NaN  ...                                                NaN
#
# [6 rows x 3 columns]

# %%
df
# Out:
#          username  ...                                            content
# 0   srinivas_shaz  ...  @Dev_Fadnavis Please Send Some Vaccines to Vas...
# 1        XCritter  ...  @Penseursauvage Ne fais pas l'amalgame entre c...
# 2     DavidPember  ...  @RonnieMathis2 @Value_IS_KING @BarstoolMintzy ...
# 3       Toni_Cwen  ...  @PabloSnicklefrz Faye sez hi! https://t.co/m7U...
# 4      Bebs______  ...  T'imagines si en plus de ne pas être vacciné, ...
# ..            ...  ...                                                ...
# 95       gmfuster  ...  @DrEricDing Chile had the Chinese vaccine thou...
# 96   lostmixtapes  ...  astro pls wait until i get my vaccine now befo...
# 97  VaxHuntersCan  ...        @LisaPBRI If that is York Region, then yes.
# 98      Bloonface  ...  I was (and I suppose still am?) in favour of l...
# 99       Hendo968  ...                @trellejb Liking anti vaccine stuff
#
# [100 rows x 3 columns]

# %%
df['content']
# Out:
# 0     @Dev_Fadnavis Please Send Some Vaccines to Vas...
# 1     @Penseursauvage Ne fais pas l'amalgame entre c...
# 2     @RonnieMathis2 @Value_IS_KING @BarstoolMintzy ...
# 3     @PabloSnicklefrz Faye sez hi! https://t.co/m7U...
# 4     T'imagines si en plus de ne pas être vacciné, ...
#                             ...
# 95    @DrEricDing Chile had the Chinese vaccine thou...
# 96    astro pls wait until i get my vaccine now befo...
# 97          @LisaPBRI If that is York Region, then yes.
# 98    I was (and I suppose still am?) in favour of l...
# 99                  @trellejb Liking anti vaccine stuff
# Name: content, Length: 100, dtype: object

# %%
# 1. Buruk
# 2. Netral
# 3. Baik
df = df.drop(columns=['username', 'date'])

# %%
df
# Out:
#                                               content
# 0   @Dev_Fadnavis Please Send Some Vaccines to Vas...
# 1   @Penseursauvage Ne fais pas l'amalgame entre c...
# 2   @RonnieMathis2 @Value_IS_KING @BarstoolMintzy ...
# 3   @PabloSnicklefrz Faye sez hi! https://t.co/m7U...
# 4   T'imagines si en plus de ne pas être vacciné, ...
# ..                                                ...
# 95  @DrEricDing Chile had the Chinese vaccine thou...
# 96  astro pls wait until i get my vaccine now befo...
# 97        @LisaPBRI If that is York Region, then yes.
# 98  I was (and I suppose still am?) in favour of l...
# 99                @trellejb Liking anti vaccine stuff
#
# [100 rows x 1 columns]

# %%
df.content=df.content.astype(str)

# %%
df
# Out:
#                                               content
# 0   @Dev_Fadnavis Please Send Some Vaccines to Vas...
# 1   @Penseursauvage Ne fais pas l'amalgame entre c...
# 2   @RonnieMathis2 @Value_IS_KING @BarstoolMintzy ...
# 3   @PabloSnicklefrz Faye sez hi! https://t.co/m7U...
# 4   T'imagines si en plus de ne pas être vacciné, ...
# ..                                                ...
# 95  @DrEricDing Chile had the Chinese vaccine thou...
# 96  astro pls wait until i get my vaccine now befo...
# 97        @LisaPBRI If that is York Region, then yes.
# 98  I was (and I suppose still am?) in favour of l...
# 99                @trellejb Liking anti vaccine stuff
#
# [100 rows x 1 columns]

# %%
df.to_csv('/content/drive/MyDrive/SA BISA AI/Mini Bootcamp Juni/dataset.csv', index=None)

# %%
df.shape
# Out:
# (100, 1)

# %%
df.size
# Out:
# 100

# %%
df.isna().any()
# Out:
# content    False
# dtype: bool

# %%
df.isna().sum()
# Out:
# content    0
# dtype: int64

# %%
df2 = pd.read_csv('dataset.csv')
